# %%
nltk, spacy 
'esc' + 'a' ===> new cell above
'esc' + 'b' ===> new cell below
'esc' + 'dd'--> delete a cell
shift + enter

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm 
#en_core_web_md, en_core_web_lg, en
# Out:
# Requirement already satisfied: spacy in c:\users\nc\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (8.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (3.0.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (2.0.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (2.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: pathy in c:\users\nc\anaconda3\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (2.24.0)
# Requirement already satisfied: jinja2 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (20.4)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (1.7.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (1.19.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: setuptools in c:\users\nc\anaconda3\lib\site-packages (from spacy) (50.3.1.post20201107)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy) (4.50.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\nc\anaconda3\lib\site-packages (from pathy->spacy) (3.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nc\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nc\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: six in c:\users\nc\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (1.15.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\nc\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in c:\users\nc\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\nc\anaconda3\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.2)
# Requirement already satisfied: setuptools in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.24.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: jinja2 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.1)
# Requirement already satisfied: pathy in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.50.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nc\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\nc\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nc\anaconda3\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nc\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: six in c:\users\nc\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\nc\anaconda3\lib\site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Natural Language Understanding

# %% [markdown]
# *Generic Data cleaning steps to take:*
#
# **1. Converting text to lower case**
# * if your data is case insensitive, you'll need to consider your usecase as well
# * some exceptions, if there're acronyms, which may lose their meaning if converted to word, e.g. in german language, MIT (university) vs mit (german for with)
#
# **2. Removing punctuations**
# * exceptions, twitter data, where punctuations may be good in showing sentiment
#
# **3. Removing any numerical values**
#
# **4. Tokenize text**
# * different ways to tokenize the text
#
# **5. Remove stop words**
# * stop words can be altered to be usecase specific,
# * e.g. adding restaurant name to list of stopwords for restaurant review, as the people will usually give the restaurant name in the review
# * e.g. twitter you may want to add words like 'RT' 'Retweet' etc for tweets
#
#
# **6. Stemming / lemmatization**
# * different variation of words due to suffix, but the meaning of the word is the same, use of the word is identical, to prevent duplication of words being stored and improve efficiency
# * lemmatization result is a proper word, unlike stemming
#
#
# **7. Parts of speech tagging**
# * good for identifying, summarising, to get e.g. retrieval of nouns from large pieces of texts (NNP)
#
# **8. Create bi-grams or tri-grams**
#
# **9. Deal with typos and spelling mistakes**

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Tokenisation

# %%
regular expression
# Out:
#   File "<ipython-input-8-890fd7fe702d>", line 1
#     regular expression
#             ^
# SyntaxError: invalid syntax

# %%
para = nlp('''Hello Mr. Tan, this is the first sentence. 
           This is the second sentence. 
           Notice, the abbreviations, e.g. Mr. Goh, Ms. Ng, do not get tokenised wrongly.''')

# %%
for sent in para.sents:
    print(sent)
# Out:
# Hello Mr. Tan, this is the first sentence.
#
#
# This is the second sentence.
#
#            Notice, the abbreviations, e.g. Mr. Goh, Ms. Ng, do not get tokenised wrongly.

# %%
sentence = nlp('I went to the nearby grocers to buy ten oranges and 5 apples.')

# %%
all_stopwords = nlp.Defaults.stop_words

# %%
for word in sentence:
    print(word, word.is_stop)
# Out:
# I True
# went False
# to True
# the True
# nearby False
# grocers False
# to True
# buy False
# ten True
# oranges False
# and True
# 5 False
# apples False
# . False

# %%
tokens = [token.text for token in sentence if not token.is_stop]

# %%
tokens
# Out:
# ['went', 'nearby', 'grocers', 'buy', 'oranges', '5', 'apples', '.']

# %%
all_stopwords
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
type(all_stopwords)
# Out:
# set

# %%
all_stopwords.add('retweet') # RT,

# %%
all_stopwords.update({'zooloo','zzz'})

# %%
all_stopwords
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'retweet',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'zooloo',
#  'zzz',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
all_stopwords.remove('single') #discard
all_stopwords.difference_update({'multiple','to','remove'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-c5b440141755> in <module>
# ----> 1 all_stopwords.remove('single') #discard
#       2 all_stopwords.difference_update({'multiple','to','remove'})
#
# KeyError: 'single'

# %% [markdown]
# # Lemmatization

# %%
doc = nlp('She was better than the best in atheletics. She was a great runner. Running was her passion.')

# %%
for token in doc:
    print(token, token.lemma_)
# Out:
# She she
# was be
# better well
# than than
# the the
# best good
# in in
# atheletics atheletic
# . .
# She she
# was be
# a a
# great great
# runner runner
# . .
# Running running
# was be
# her her
# passion passion
# . .

# %%
doing stemming -- > NLTK natural language toolkit for python, porter stemmer and snowball stemmer
# Out:
#   File "<ipython-input-29-e1107cd3b8a1>", line 1
#     doing stemming -- > NLTK natural language toolkit for python, porter stemmer and snowball stemmer
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Part of Speech Tags

# %%
# For each token, print corresponding part of speech tag
for token in para:
    print('{} - {}'.format(token, token.pos_))

# %%
sentence = nlp('He left his keys in his left pocket.')

for token in sentence:
    print('{} - {}'.format(token, token.pos_))

# %% [markdown]
# # Named Entity Recognition

# %%
finetune spacy language model

# %%
# Print all named entities with named entity types

doc_2 = nlp("I went out with Jane to the Apple store in Orchard to buy an iphone. It cost me $800. After that I stopped for an apple pie.")
for ent in doc_2.ents:
    print('{} - {}'.format(ent, ent.label_))

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# Data Source: https://www.kaggle.com/c/sentiment-analysis-on-movie-reviews
#
#
# The dataset is comprised of tab-separated files with phrases from the Rotten Tomatoes dataset. The train/test split has been preserved for the purposes of benchmarking, but the sentences have been shuffled from their original order. Each Sentence has been parsed into many phrases by the Stanford parser. Each phrase has a PhraseId. Each sentence has a SentenceId. Phrases that are repeated (such as short/common words) are only included once in the data.
#
# train.tsv contains the phrases and their associated sentiment labels. We have additionally provided a SentenceId so that you can track which phrases belong to a single sentence.
# test.tsv contains just phrases. You must assign a sentiment label to each phrase.
# The sentiment labels are:
#
# 0 - negative
# 1 - somewhat negative
# 2 - neutral
# 3 - somewhat positive
# 4 - positive

# %%
df = pd.read_csv('train.tsv', sep='\t')

# %%
Sentiment_count = df.groupby('Sentiment').count()

plt.bar(Sentiment_count.index.values, Sentiment_count['Phrase'])
plt.xlabel('Review Sentiments')
plt.ylabel('Number of Review')
plt.show()

# %%
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')

cv = CountVectorizer(lowercase=True, stop_words='english', ngram_range = (1,1), tokenizer = token.tokenize)

text_counts= cv.fit_transform(df['Phrase'])

# %%
X_train, X_test, y_train, y_test = train_test_split(text_counts, df['Sentiment'], test_size=0.3, random_state=1)

# %%
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted = clf.predict(X_test)

print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))

# %%
tf = TfidfVectorizer()

text_tf = tf.fit_transform(df['Phrase'])

# %%
X_train, X_test, y_train, y_test = train_test_split(text_tf, df['Sentiment'], test_size=0.3, random_state=123)

# %%
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)

print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))

# %% [markdown]
# 1. **TextBlob Module:** Linguistic researchers have labeled the sentiment of words based on their domain expertise. Sentiment of words can vary based on where it is in a sentence. The TextBlob module allows us to take advantage of these labels.
# 2. **Sentiment Labels:** Each word in a corpus is labeled in terms of polarity and subjectivity (there are more labels as well, but we're going to ignore them for now). A corpus' sentiment is the average of these.
#    * **Polarity**: How positive or negative a word is. -1 is very negative. +1 is very positive.
#    * **Subjectivity**: How subjective, or opinionated a word is. 0 is fact. +1 is very much an opinion.
#
# For more info on how TextBlob coded up its [sentiment function](https://planspace.org/20150607-textblob_sentiment/).
#
# Let's take a look at the sentiment of the various transcripts, both overall and throughout the comedy routine.

# %%
#!pip install spacytextblob

# %%
from spacytextblob.spacytextblob import SpacyTextBlob
spacy_text_blob = SpacyTextBlob()
nlp.add_pipe(spacy_text_blob)
text = 'I had a really horrible day. It was the worst day ever! But every now and then I have a really good day that makes me happy.'
doc = nlp(text)

# %%
doc._.sentiment.polarity      # Polarity: -0.125

# %%
doc._.sentiment.subjectivity  # Sujectivity: 0.9

# %%
doc._.sentiment.assessments

# %%
def scrape_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, "html.parser")
    lyrics = html.find("pre", class_="lyric-body").get_text()
    print(url)
    #print(lyrics)
    return lyrics.replace("\n"," ")


links = ['https://www.lyrics.com/lyric/36863481/Justin+Bieber/Yummy',
     'https://www.lyrics.com/lyric/35362456/Ed+Sheeran/Castle+on+the+Hill',
     'https://www.lyrics.com/lyric/35342586/Taylor+Swift/22',
     'https://www.lyrics.com/lyric/36147543/Kygo/Happy+Now',
     'https://www.lyrics.com/sublyric/58125/Lauv/Superhero',
     'https://www.lyrics.com/lyric/30514737/Fix+You',
     'https://www.lyrics.com/lyric/32981724/One+Direction/Perfect',
     'https://www.lyrics.com/lyric/36489666/Bahari/Crashing',
     'https://www.lyrics.com/lyric/33787626/ROZES/Matches',
     'https://www.lyrics.com/lyric/36341880/Maroon+5/She+Will+Be+Loved',
     'https://www.lyrics.com/lyric/25306933/Queen/Dont+Stop+Me+Now',
     'https://www.lyrics.com/lyric/31781320/Eric+Clapton/Tears+In+Heaven']


lyrics = [scrape_lyrics(link) for link in links]

artists = ['JustinBieber', 'EdSheeran', 'TaylorSwift', 'Kygo', 'Lauv', 'Coldplay', 'OneDirection','Bahari','Rozes','Maroon5', 'Queen', 'EricClapton']

#fun fact: queen dont stop me now is apparently the happiest song, and eric clapton is supposedly a sad song
# https://www.indy100.com/article/dont-stop-me-now-is-the-happiest-song-in-the-world-according-to-a-neuroscientist-7318321
#but there's more to the what affects the sentiment of the song, not just the lyrics, e.g. tempo

# %%
df = pd.DataFrame({'Lyrics':lyrics}, index=artists)

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity
df['polarity'] = df['Lyrics'].apply(pol)
df['subjectivity'] = df['Lyrics'].apply(sub)

plt.rcParams['figure.figsize'] = [10, 8]

for artist in df.index:
    x = df.polarity.loc[artist]
    y = df.subjectivity.loc[artist]
    plt.scatter(x, y, color='green')
    plt.text(x+.001, y+.001, artist, fontsize=10)
    plt.xlim(-.7, .7) 
    plt.ylim(0,1) 
    
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<-- Negative ---------- Positive -->', fontsize=15)
plt.ylabel('<-- Facts -------- Opinions -->', fontsize=15)

plt.show()
